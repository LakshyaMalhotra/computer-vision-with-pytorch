# %%
# necessary imports
import os
import time
import random

import torch
import torchinfo
import albumentations as A
import cv2 as cv
import numpy as np
import pandas as pd
import torch.nn as nn
import seaborn as sns
import matplotlib.pyplot as plt
import torch.nn.functional as F
from torchmetrics import Accuracy
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from sklearn.model_selection import train_test_split

sns.set_theme(style="darkgrid", palette="muted")

# %%
def seed_basic(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
# torch random seed
def seed_torch(seed):
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
      
# basic + torch 
def seed_everything(seed=23):
    seed_basic(seed)
    seed_torch(seed)

# %%
DEFAULT_RANDOM_SEED = 2022
seed_everything(DEFAULT_RANDOM_SEED)

# %%
# define data path
base_path = os.path.dirname(os.getcwd())
base_path = os.path.join(base_path, "data/describable_textures_dtd")
meta_data = "unbalanced_data.csv"

# %%
# load the meta data
df = pd.read_csv(os.path.join(base_path, meta_data))
df.head(2)
# Out:
#   class_name  class_id          file_name
# 0      scaly        33     scaly_0154.jpg
# 1   potholed        32  potholed_0161.jpg

# %%
# train test split, stratify according to class ids
y = df.class_id
train_df, valid_df = train_test_split(df, test_size=300, stratify=y)

# %%
y.nunique()
# Out:
# 47

# %%
# image augmentations
transforms = A.Compose([
    A.Resize(224, 224)
])

# %%
# create pytorch dataset
class PatternDataset(Dataset):
    def __init__(self, base_path:str, data:pd.DataFrame, tfms:A.Compose=None):
        self.base_path =base_path
        self.images_dir = os.path.join(self.base_path, "images")
        self.data = data
        self.tfms = tfms
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx:int):
        row = self.data.iloc[idx]
        target = row.class_id
        img_path = os.path.join(self.images_dir, row.class_name, row.file_name)
        img = cv.imread(img_path)
        img = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
        img = img / 255. 
        if self.tfms is not None:
            img = self.tfms(image=img)["image"]
        
        img = img[np.newaxis, ...]
        img = torch.tensor(img, dtype=torch.float32)
        target = torch.tensor(target, dtype=torch.long)
        return img, target

# %%
# create datasets
train_dataset = PatternDataset(base_path, data=train_df, tfms=transforms)
valid_dataset = PatternDataset(base_path, data=valid_df, tfms=transforms)

# %%
# get class weights
class_sample_counts = train_df.class_id.value_counts().values
weights = 1. / torch.tensor(class_sample_counts, dtype=torch.float)
train_targets = train_df.class_id.values
sample_weights = weights[train_targets]

# %%
# create samplers
train_sampler = WeightedRandomSampler(
    sample_weights, num_samples=len(sample_weights), replacement=True
)

# create dataloaders
train_loader = DataLoader(
    train_dataset,
    batch_size=64,
    shuffle=False,
    pin_memory=True,
    sampler=train_sampler,
)
valid_loader = DataLoader(
    valid_dataset, batch_size=32, shuffle=False, pin_memory=True
)

dataloaders = {"train": train_loader, "valid": valid_loader}

# %%
# model
class CNNModel(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=(3, 3))
        self.maxpool1 = nn.MaxPool2d(kernel_size=2)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=(3, 3))
        self.maxpool2 = nn.MaxPool2d(kernel_size=2)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=(3, 3))
        self.maxpool3 = nn.MaxPool2d(kernel_size=2)
        self.conv4 = nn.Conv2d(64, 128, kernel_size=(3, 3))
        self.maxpool4 = nn.MaxPool2d(kernel_size=2)
        self.conv5 = nn.Conv2d(128, 128, kernel_size=(3, 3))
        self.maxpool5 = nn.MaxPool2d(kernel_size=2)

        self.fc1 = nn.LazyLinear(out_features=256)
        self.dropout = nn.Dropout(p=0.25)
        self.fc2 = nn.Linear(in_features=256, out_features=num_classes)

    def forward(self, x):
        x = self.maxpool1(self.conv1(x))
        x = F.relu(x)
        x = self.maxpool2(self.conv2(x))
        x = F.relu(x)
        x = self.maxpool3(self.conv3(x))
        x = F.relu(x)
        x = self.maxpool4(self.conv4(x))
        x = F.relu(x)
        x = self.maxpool5(self.conv5(x))
        x = F.relu(x)

        x = x.view(x.size(0), -1)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)
        return x

# %%
# create model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = CNNModel(num_classes=y.nunique())
x = torch.rand(4, 1, 224, 224)
out = model(x)
print(out.size())
torchinfo.summary(model, x.size(), device="cpu")
# Out:
# torch.Size([4, 47])
# /home/lakshya/miniconda3/envs/pt/lib/python3.9/site-packages/torch/nn/modules/lazy.py:178: UserWarning: Lazy modules are a new feature under heavy development so changes to the API or functionality can happen at any moment.
#   warnings.warn('Lazy modules are a new feature under heavy development '
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# CNNModel                                 [4, 47]                   --
# ├─Conv2d: 1-1                            [4, 16, 222, 222]         160
# ├─MaxPool2d: 1-2                         [4, 16, 111, 111]         --
# ├─Conv2d: 1-3                            [4, 32, 109, 109]         4,640
# ├─MaxPool2d: 1-4                         [4, 32, 54, 54]           --
# ├─Conv2d: 1-5                            [4, 64, 52, 52]           18,496
# ├─MaxPool2d: 1-6                         [4, 64, 26, 26]           --
# ├─Conv2d: 1-7                            [4, 128, 24, 24]          73,856
# ├─MaxPool2d: 1-8                         [4, 128, 12, 12]          --
# ├─Conv2d: 1-9                            [4, 128, 10, 10]          147,584
# ├─MaxPool2d: 1-10                        [4, 128, 5, 5]            --
# ├─Linear: 1-11                           [4, 256]                  819,456
# ├─Dropout: 1-12                          [4, 256]                  --
# ├─Linear: 1-13                           [4, 47]                   12,079
# ==========================================================================================
# Total params: 1,076,271
# Trainable params: 1,076,271
# Non-trainable params: 0
# Total mult-adds (M): 684.63
# ==========================================================================================
# Input size (MB): 0.80
# Forward/backward pass size (MB): 45.72
# Params size (MB): 4.31
# Estimated Total Size (MB): 50.82
# ==========================================================================================

# %%
# define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device
# Out:
# device(type='cuda')

# %%
def train(
    n_epochs,
    dataloaders,
    model,
    accuracy,
    optimizer,
    criterion,
    device,
    scheduler=None,
):
    start = time.time()

    # monitor training and validation losses
    train_losses, train_accuracies = [], []
    valid_losses, valid_accuracies = [], []

    # iterate through all the epochs
    for epoch in range(1, n_epochs + 1):
        train_epoch_losses, train_epoch_accuracies = [], []
        valid_epoch_losses, valid_epoch_accuracies = [], []
        epoch_start = time.time()

        # put the model to training mode
        model.train()
        for (images, targets) in dataloaders["train"]:
            images = images.to(device)
            targets = targets.to(device)

            # clear any accumulated gradients
            optimizer.zero_grad()

            # feed forward
            predictions = model(images)

            # calculate the loss
            loss = criterion(predictions, targets)

            # backprop
            loss.backward()

            # optimizer step
            optimizer.step()

            # store batch loss and accuracy
            train_epoch_losses.append(loss.item())

            batch_accuracy = accuracy(predictions, targets)
            # train_epoch_accuracies.extend(batch_accuracy.cpu().numpy())
            train_epoch_accuracies.append(batch_accuracy.item())
            # print(f"train epoch accuracies: {train_epoch_accuracies}")
        train_epoch_loss = np.mean(train_epoch_losses)
        train_epoch_accuracy = np.mean(train_epoch_accuracies) * 100

        # evaluate
        model.eval()
        for (images, targets) in dataloaders["valid"]:
            images = images.to(device)
            targets = targets.to(device)

            # compute predictions with no backprop
            with torch.no_grad():
                predictions = model(images)

                # calculate the loss
                loss = criterion(predictions, targets)

            # store batch loss and accuracy
            valid_epoch_losses.append(loss.item())

            # batch_accuracy = accuracy(predictions, targets)
            # valid_epoch_accuracies.extend(batch_accuracy.cpu().numpy())
            batch_accuracy = accuracy(predictions, targets)
            # train_epoch_accuracies.extend(batch_accuracy.cpu().numpy())
            valid_epoch_accuracies.append(batch_accuracy.item())
            # print(f"train epoch accuracies: {train_epoch_accuracies}")

        valid_epoch_loss = np.mean(valid_epoch_losses)
        valid_epoch_accuracy = np.mean(valid_epoch_accuracies) * 100

        train_losses.append(train_epoch_loss)
        train_accuracies.append(train_epoch_accuracy)

        valid_losses.append(valid_epoch_loss)
        valid_accuracies.append(valid_epoch_accuracy)

        if scheduler is not None:
            scheduler.step(valid_epoch_loss)

        print(
            f"Epoch {epoch:02d} / {n_epochs:02d} \tTime taken:{(time.time() - epoch_start):.2f} seconds"
        )
        print(
            f"Training loss: {train_epoch_loss:5f} \tValidation loss: {valid_epoch_loss:5f}"
        )
        print(
            f"Training accuracy: {train_epoch_accuracy:.3f} \tValidation accuracy: {valid_epoch_accuracy:.3f}"
        )
    print(f"Training finished in {(time.time()-start):.2f} seconds.")

    return train_losses, valid_losses, train_accuracies, valid_accuracies


def plot_metrics(
    train_losses, train_accuracies, valid_losses, valid_accuracies
):
    fig, ax = plt.subplots(2, 1, sharex=True, figsize=(6, 8), dpi=150)
    fig.suptitle("Unbalanced classes weighted sampler")

    x = range(1, len(train_losses) + 1)
    ax[0].plot(x, train_losses, label="Train")
    ax[0].plot(x, valid_losses, label="Valid")
    ax[0].legend(frameon=False, fontsize=8)
    # ax[0].xaxis.set_major_locator(ticker.MultipleLocator(1))
    # ax[0].tick_params(axis="both", which="both", labelsize=8)
    ax[0].set_title("Loss", fontsize=10)

    ax[1].plot(x, train_accuracies, label="Train")
    ax[1].plot(x, valid_accuracies, label="Valid")
    ax[1].legend(frameon=False, fontsize=8)
    # ax[1].xaxis.set_major_locator(plt.MultipleLocator(2))
    # ax[1].tick_params(axis="x", which="both", labelsize=7)
    ax[1].set_xlabel("Epoch", fontsize=9)
    ax[1].set_title("Accuracy", fontsize=10)

    fig.tight_layout()
    plt.show()


# def weight_init(m: nn.Module):
#     if isinstance(m, nn.Conv2d) or isinstance(m, nn.Linear):
#         nn.init.kaiming_uniform_(m.weight)
#         nn.init.zeros_(m.bias)


def main(n_epochs, model, criterion, optimizer, dataloaders, device):
    # get dataloaders
    # dataloaders = get_dataloaders(batch_size=batch_size)
    print(f"Number of training batches: {len(dataloaders['train'])}")
    print(f"Number of validation batches: {len(dataloaders['valid'])}")
    images, labels = next(iter(dataloaders["train"]))
    print(f"Images shape: {images[0].shape}")
    print(f"Labels shape: {labels[0]}")
    print(f"Using device: {device}")

    # put model to device
    model = model.to(device)

    # define accuracy
    accuracy = Accuracy(threshold=0.6).to(device)

    # learning rate scheduler
    # scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    #     optimizer, "min", verbose=True, factor=0.6, patience=4
    # )

    # train and evaluate
    train_losses, valid_losses, train_accuracies, valid_accuracies = train(
        n_epochs,
        dataloaders,
        model,
        accuracy,
        optimizer,
        criterion,
        device,
        # scheduler,
    )

    # plot the results
    plot_metrics(
        train_losses, train_accuracies, valid_losses, valid_accuracies
    )

# %%
main(50, model, criterion, optimizer, dataloaders, device)
# Out:
# Number of training batches: 47
# Number of validation batches: 10
# Images shape: torch.Size([1, 224, 224])
# Labels shape: 35
# Using device: cuda
# Epoch 01 / 50 	Time taken:11.20 seconds
# Training loss: 3.692551 	Validation loss: 3.894483
# Training accuracy: 9.484 	Validation accuracy: 2.812
# Epoch 02 / 50 	Time taken:8.80 seconds
# Training loss: 3.600209 	Validation loss: 3.992083
# Training accuracy: 10.785 	Validation accuracy: 2.188
# Epoch 03 / 50 	Time taken:9.06 seconds
# Training loss: 3.581699 	Validation loss: 3.891475
# Training accuracy: 10.904 	Validation accuracy: 3.750
# Epoch 04 / 50 	Time taken:8.87 seconds
# Training loss: 3.557886 	Validation loss: 3.981236
# Training accuracy: 12.465 	Validation accuracy: 5.312
# Epoch 05 / 50 	Time taken:8.89 seconds
# Training loss: 3.488262 	Validation loss: 3.798974
# Training accuracy: 14.497 	Validation accuracy: 5.312
# Epoch 06 / 50 	Time taken:8.88 seconds
# Training loss: 3.434112 	Validation loss: 3.793219
# Training accuracy: 15.667 	Validation accuracy: 4.375
# Epoch 07 / 50 	Time taken:9.15 seconds
# Training loss: 3.385284 	Validation loss: 3.751281
# Training accuracy: 17.010 	Validation accuracy: 5.938
# Epoch 08 / 50 	Time taken:8.98 seconds
# Training loss: 3.354198 	Validation loss: 3.776441
# Training accuracy: 17.223 	Validation accuracy: 5.625
# Epoch 09 / 50 	Time taken:9.21 seconds
# Training loss: 3.291667 	Validation loss: 3.751036
# Training accuracy: 18.706 	Validation accuracy: 5.312
# Epoch 10 / 50 	Time taken:8.50 seconds
# Training loss: 3.256712 	Validation loss: 3.659213
# Training accuracy: 19.034 	Validation accuracy: 5.625
# Epoch 11 / 50 	Time taken:8.88 seconds
# Training loss: 3.228527 	Validation loss: 3.653822
# Training accuracy: 19.574 	Validation accuracy: 5.938
# Epoch 12 / 50 	Time taken:8.61 seconds
# Training loss: 3.240752 	Validation loss: 3.630547
# Training accuracy: 18.905 	Validation accuracy: 6.562
# Epoch 13 / 50 	Time taken:8.81 seconds
# Training loss: 3.175819 	Validation loss: 3.649342
# Training accuracy: 19.945 	Validation accuracy: 5.625
# Epoch 14 / 50 	Time taken:8.77 seconds
# Training loss: 3.117466 	Validation loss: 3.603037
# Training accuracy: 21.294 	Validation accuracy: 8.125
# Epoch 15 / 50 	Time taken:8.88 seconds
# Training loss: 3.129437 	Validation loss: 3.540987
# Training accuracy: 20.829 	Validation accuracy: 8.125
# Epoch 16 / 50 	Time taken:8.80 seconds
# Training loss: 3.037243 	Validation loss: 3.562802
# Training accuracy: 22.813 	Validation accuracy: 8.750
# Epoch 17 / 50 	Time taken:8.38 seconds
# Training loss: 2.984767 	Validation loss: 3.487321
# Training accuracy: 23.256 	Validation accuracy: 9.688
# Epoch 18 / 50 	Time taken:8.71 seconds
# Training loss: 2.982712 	Validation loss: 3.575964
# Training accuracy: 24.233 	Validation accuracy: 10.000
# Epoch 19 / 50 	Time taken:8.92 seconds
# Training loss: 2.916970 	Validation loss: 3.450224
# Training accuracy: 25.847 	Validation accuracy: 9.688
# Epoch 20 / 50 	Time taken:8.91 seconds
# Training loss: 2.803134 	Validation loss: 3.452479
# Training accuracy: 27.396 	Validation accuracy: 12.188
# Epoch 21 / 50 	Time taken:8.68 seconds
# Training loss: 2.770018 	Validation loss: 3.403426
# Training accuracy: 29.266 	Validation accuracy: 14.271
# Epoch 22 / 50 	Time taken:8.47 seconds
# Training loss: 2.747078 	Validation loss: 3.448910
# Training accuracy: 29.661 	Validation accuracy: 14.688
# Epoch 23 / 50 	Time taken:8.58 seconds
# Training loss: 2.645700 	Validation loss: 3.357207
# Training accuracy: 31.642 	Validation accuracy: 13.750
# Epoch 24 / 50 	Time taken:8.86 seconds
# Training loss: 2.568840 	Validation loss: 3.414452
# Training accuracy: 33.276 	Validation accuracy: 13.125
# Epoch 25 / 50 	Time taken:8.73 seconds
# Training loss: 2.499030 	Validation loss: 3.414818
# Training accuracy: 35.496 	Validation accuracy: 14.375
# Epoch 26 / 50 	Time taken:8.76 seconds
# Training loss: 2.385533 	Validation loss: 3.351027
# Training accuracy: 37.504 	Validation accuracy: 16.562
# Epoch 27 / 50 	Time taken:8.94 seconds
# Training loss: 2.329753 	Validation loss: 3.303100
# Training accuracy: 38.874 	Validation accuracy: 15.000
# Epoch 28 / 50 	Time taken:8.67 seconds
# Training loss: 2.257002 	Validation loss: 3.304507
# Training accuracy: 41.992 	Validation accuracy: 17.188
# Epoch 29 / 50 	Time taken:8.69 seconds
# Training loss: 2.191244 	Validation loss: 3.244864
# Training accuracy: 43.608 	Validation accuracy: 18.125
# Epoch 30 / 50 	Time taken:8.56 seconds
# Training loss: 2.065116 	Validation loss: 3.466919
# Training accuracy: 46.228 	Validation accuracy: 16.146
# Epoch 31 / 50 	Time taken:8.58 seconds
# Training loss: 2.118002 	Validation loss: 3.387279
# Training accuracy: 45.357 	Validation accuracy: 19.167
# Epoch 32 / 50 	Time taken:8.46 seconds
# Training loss: 2.029777 	Validation loss: 3.270396
# Training accuracy: 46.192 	Validation accuracy: 19.479
# Epoch 33 / 50 	Time taken:9.19 seconds
# Training loss: 1.926540 	Validation loss: 3.519750
# Training accuracy: 48.954 	Validation accuracy: 15.833
# Epoch 34 / 50 	Time taken:9.26 seconds
# Training loss: 1.866761 	Validation loss: 3.392915
# Training accuracy: 49.781 	Validation accuracy: 18.646
# Epoch 35 / 50 	Time taken:8.79 seconds
# Training loss: 1.839573 	Validation loss: 3.353232
# Training accuracy: 51.518 	Validation accuracy: 18.750
# Epoch 36 / 50 	Time taken:8.97 seconds
# Training loss: 1.712689 	Validation loss: 3.488229
# Training accuracy: 54.683 	Validation accuracy: 19.271
# Epoch 37 / 50 	Time taken:8.77 seconds
# Training loss: 1.691588 	Validation loss: 3.637552
# Training accuracy: 54.497 	Validation accuracy: 15.937
# Epoch 38 / 50 	Time taken:8.62 seconds
# Training loss: 1.604364 	Validation loss: 3.641337
# Training accuracy: 56.953 	Validation accuracy: 18.750
# Epoch 39 / 50 	Time taken:8.68 seconds
# Training loss: 1.519501 	Validation loss: 3.625147
# Training accuracy: 59.459 	Validation accuracy: 17.812
# Epoch 40 / 50 	Time taken:8.88 seconds
# Training loss: 1.505337 	Validation loss: 3.663005
# Training accuracy: 58.910 	Validation accuracy: 21.146
# Epoch 41 / 50 	Time taken:8.77 seconds
# Training loss: 1.432951 	Validation loss: 3.829960
# Training accuracy: 60.847 	Validation accuracy: 21.979
# Epoch 42 / 50 	Time taken:8.75 seconds
# Training loss: 1.410198 	Validation loss: 3.829647
# Training accuracy: 61.633 	Validation accuracy: 19.896
# Epoch 43 / 50 	Time taken:8.81 seconds
# Training loss: 1.298684 	Validation loss: 3.936238
# Training accuracy: 64.894 	Validation accuracy: 20.312
# Epoch 44 / 50 	Time taken:8.99 seconds
# Training loss: 1.240302 	Validation loss: 3.825518
# Training accuracy: 65.960 	Validation accuracy: 20.625
# Epoch 45 / 50 	Time taken:9.28 seconds
# Training loss: 1.254472 	Validation loss: 3.898369
# Training accuracy: 64.807 	Validation accuracy: 20.000
# Epoch 46 / 50 	Time taken:8.95 seconds
# Training loss: 1.207303 	Validation loss: 4.000307
# Training accuracy: 66.649 	Validation accuracy: 21.146
# Epoch 47 / 50 	Time taken:9.02 seconds
# Training loss: 1.139241 	Validation loss: 4.056919
# Training accuracy: 69.656 	Validation accuracy: 19.688
# Epoch 48 / 50 	Time taken:8.56 seconds
# Training loss: 1.094246 	Validation loss: 4.062407
# Training accuracy: 70.547 	Validation accuracy: 19.896
# Epoch 49 / 50 	Time taken:8.72 seconds
# Training loss: 1.083917 	Validation loss: 4.128943
# Training accuracy: 69.670 	Validation accuracy: 23.438
# Epoch 50 / 50 	Time taken:8.56 seconds
# Training loss: 1.018752 	Validation loss: 4.182225
# Training accuracy: 72.571 	Validation accuracy: 19.583
# Training finished in 442.78 seconds.
